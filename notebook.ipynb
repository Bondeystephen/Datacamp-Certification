# %% [markdown]
# # Data Analyst Professional Practical Exam Submission
#
# **You can use any tool that you want to do your analysis and create visualizations. Use this template to write up your summary for submission.**
#
# You can use any markdown formatting you wish. If you are not familiar with Markdown, read the [Markdown Guide](https://s3.amazonaws.com/talent-assets.datacamp.com/Markdown+Guide.pdf) before you start.

# %% [markdown]
# ## 📝 Task List
#
# Your written report should include written text summaries and graphics of the following:
# - Data validation:
#   - Describe validation and cleaning steps for every column in the data
# - Exploratory Analysis:
#   - Include two different graphics showing single variables only to demonstrate the characteristics of data
#   - Include at least one graphic showing two or more variables to represent the relationship between features
#   - Describe your findings
# - Definition of a metric for the business to monitor
#   - How should the business use the metric to monitor the business problem
#   - Can you estimate initial value(s) for the metric based on the current data
# - Final summary including recommendations that the business should undertake
#
# *Start writing report here..*

# %% [markdown]
# ### Data Validation
# The dataset contains **15000 rows** and **8 columns** before cleaning and validataion. I have validated all the columns against the criteria in the dataset table:
#
# - week: It has 6 weeks, numeric values without missing values, same as the description. No cleaning is needed.
# - sales_method: 3 methods were used to reach out to the 15,000 customers. While analyzing the column, I observed that it had five categories instead of three due to capitilization. I then mapped the values into three distinct categories 'Email', 'Call', 'Emaill+Call'. No missing values.
#
# - customer_id:character 15,000 unique values without missing number. No cleaning is needed.
# - nb_sold: numeric values, no missing values, 10 unique number of products sold. No cleaning is needed.
#
# - revenue: numeric values, 1074 are null. Since 7% of the revenue are missing values appearing randomly (with no specific pattern). The column was cleaned by dropping all NAs'.
#
# - years_as_customer: 42 possible values, from 1984 the company was established, without missing values, same as description. No cleaning is needed,  with a 2 outliers identified as a customer with 47 and 63 years as customer. However, the store has been in existence for 39 years.
#
# - nb_site_visits: numeric values without missing values, same as the description. No cleaning is needed.
#
# - state: character, 50 locations of the customers, no missing number. No cleaning needed
#
#
#
# The distribution shows that most customers purchase between 8 and 12 products, with a peak at 9 and 10 around 3,500 customers for each product.There is a noticeable decline in number of customers for buying more than 10, with very few observations beyond 14 products sold.
# The distribution is aproximately normal slightly skewed to the right.
#
# .
# Products sold beyond 12 are rare, indicating these may represent outliers or a small subset of customers purchasing significantly more.
#
# ![image](image.png)
#
# The distribution of years as customers reveals that the the people that bought the new product are between 0 and 5yrs of being their customers, and a sharp decline from 6years with the normal distribution is skewed to the right.
#
# ![distribution of years as customer](distribution%20of%20years%20as%20customer.png)
#
#
# The number of visits to the website in the last 6 months is normally distributed, with an average of 25 visits per customer. More  than 1,600 customers show this,the mode, mean and median are almost similar and more than 90% of customers visited the site between 15 and 35 times. We can also see that around 5,000 customers visited the site between 24 and 26 times.
#
# ![website visit in 6 months](website%20visit%20in%206%20months.png)

# %% [markdown]
# ### How many customers were there for each approach?
# It's observed that 7466 customers were contacted via **Emails** which is almost 50% of the total sales made, and 4962 were approached via **Calls** which is almmost twice the people approached with both **Emails + calls** of 2572 sales.
#
#
# ![count by sales method](count%20by%20sales%20method.png)

# %% [markdown]
# ### What does the spread of the revenue look like overall? And for each method?
# The histogram shows several peaks at different revenue ranges, with the highest at 1600 customers on a revenue of 50, implying that revenue is coming from distinct categories of sales method due to the several peaks.
# There are more occurrences of smaller revenue values around 50 and 100. This suggests that low-revenue transactions dominate the dataset.
# In the same way, it is possible to detect few customers with higher expenses per purchase, above 200 per purchase.
#
#
#
#
# ![histogram revenue](histogram%20revenue.png)
# The line inside the boxplot represent the median closer to 100, and the presence of several outliers on the right-hand side suggests the data might be positively skewed, with a concentration of lower values and a few very high ones.
# The interquartile range reveals an approximate concentration of revenues per customer between 50.00 and 100.00.
#
#
# ![Single boxplot of revenue](Single%20boxplot%20of%20revenue.png)
#
#
#
# The boxplot of the three sales methods provides a clear visualization of the revenue distribution, confirming significant differences in their performance. The **Email** method shows a moderate interquartile range (IQR), with most revenues between 80 and 150. While there are a few outliers above 150, these higher revenue values are not representative of the majority. The **Email + Call** method demonstrates the largest IQR, ranging from approximately 120 to 230,displaying a wide variability and the highest revenue potential among the three methods. The upper whisker extends close to 240, representing the highest observed revenues, with no significant outliers in this category. However, the **Call** method displays the narrowest IQR, with revenues tightly packed between 32 and 60, reflecting limited variability and overall lower performance in revenue generation. While a few outliers exist in the Call method, the maximum revenue remains significantly lower than the other methods. Overall, the **Email + Call** method stands out as the most effective for generating high revenues, while the **Email** method provides a stable and mid-level performance, and the Call method is the least effective, with consistently lower revenue outcomes.
# ![spread by sales method](spread%20by%20sales%20method.png)

# %% [markdown]
# ## Was there any difference in revenue over time for each of the methods?
#
# From the bar chart showing revenue by sales method across 6 weeks, there are patterns and differences in revenue over time for each method.
#
# The **Email + Call** method consistently generates the highest revenue in every week, with a steady upward trend observed as the weeks progress, with the highest peak in week 6.It exhibits the strongest growth over time.
#
# The **Email method** shows relatively stable revenue generation across the six weeks, with no dramatic increases or decreases. Its performance remains consistent, falling between the high-performing Email + Call method and the lower-performing Call method.
#
# The **Call method**, on the other hand, consistently produces the lowest revenue across all weeks. There is minimal variation in its revenue performance over time compared to the other methods.
#
# Overall, while the Email + Call method demonstrates a significant upward trend in revenue over time, both the Email and Call methods exhibit more stable and less dynamic patterns, with the Call method continuing to lag behind the other approaches.
#
#
# ![revenues generated weekly](revenues%20generated%20weekly.png)

# %% [markdown]
#  ### Based on the data, which method would you recommend we continue to use? Some of these methods take more time from the team so they may not be the best for us to use if the results are similar.
#
# To better understand the dataset and pick the best method used in selling each products , there is a need to visualize the number of products sold by each methods weekly. As our aim is to increase product sales to enable our customers to be more creative, focused in brainstorming tools, I recommend that we use the **average items per transaction** and **average revenue per transaction** as metric.
# ![nb_sold](nb_sold.png)

# %% [markdown]
# ### Business Metrics
# Our goal is to ensure we are using the best techniques to sell the new product effectively. Since the **email + call** required little work from the team and the call was around ten minutes per customer according to the data analyzed from the last six weeks with the new products launched. We will be using both the number of items sold (nb_sold) and revenue as our metric:
#
# **Email** method has the highest volume of sales, with 72,639 items sold across 7,466 transactions. It also generates the highest total revenue, approximately $672,317.83.
#
# However, its average revenue per transaction is moderate at $97.04, and the average number of items per transaction is around 9.73. This makes email best suited for high-volume, lower-value sales.
#
# The combination of **Email + Call** achieves the highest average revenue per transaction at $183.61 and the highest average items per transaction at approximately 12.23.
#
# While it accounts for fewer total sales, with 31,444 items sold over 2,572 transactions and $408,256.69 revenue, this strategy delivers targeted, high-value sales, making it ideal for premium or high-value customer segments and for any type of customer if effectively used.
#
#
#
# The **Call** strategy lags behind the others, generating $227,563.49 in revenue from 47,187 items sold.
#
# It has the lowest average revenue per transaction at $47.6 and an average of 9.5 items per transaction, highlighting its lower efficiency compared to Email or Email + Call.
#
#
# Across all weeks, the **Email + Call** strategy consistently drives higher value per sale and per revenue, while Email dominates in sales volume. However, the standalone Call strategy underperforms in both revenue and items sold. There is no need using the call approach henceforth, it is cost intensive and time consuming, using an average of 30mins on call per customer.

# %% [markdown]
# ### Recommendation
# For the following weeks, I would recommend we focus on the following:
#
# If maximizing revenue is the priority and the team has sufficient resources, the **Email + Call** method should remain the primary focus.
# However, if the goal is to optimize resource use while maintaining reasonable revenue levels, the **Email method** would be a better option but you said you dont want the method producing similar results. The **Call method** should be phased out completely, as its returns do not justify its continued use.
#
# Key metrics to track include:
#
# - Revenue per transaction, particularly for Email + Call approach, and conversion rates to assess the effectiveness of each method in converting outreach into purchases.
# - Customer lifetime value should be monitored to measure long-term revenue contributions from different strategies. It's also critical to evaluate profit margins for each method, factoring in associated deployment costs, such as labor costs for calls.
# - Prioritize "Email + Call" for High-Value Sales:
# Since this method achieves the highest revenue per transaction and items per transaction, it should be used for high-value products, cross-selling, or upselling efforts.
# - Focus on high-potential customers, premium product categories, and B2B clients where relationship-building is critical.
#
# - Weekly sales trends should be analyzed to track performance changes over time as adjustments are made to prioritize "Email + Call" or scale "Email." By combining the volume-driven strength of Email and the high-value impact of Email + Call, businesses can create a balanced, data-driven strategy for optimizing both revenue and efficiency.
#
# - Email is highly effective for driving large-scale, invest in automation, personalization, and segmentation to maximize its reach and cost-efficiency.
#
# - Use calls only when direct communication is necessary, such as resolving objections or converting hesitant buyers not as a method.
#
# - Data collection for in-depth analysis: improve data quality as we have some null values in revenues— how much does the number of visits to the site by customers define the number of products to be purchased and the quantity of products to be purchased? New related data — What types of products are being purchased by customers? What is the relationship between the products sold and the revenue, there's a low revenue after Item 12,it suggests a potential pricing or sales strategy issue.
# - Are the most purchased options the Pens? Or is it the Printers? Or are the best sellers desk chairs?

# %% [markdown]
# ## ✅ When you have finished...
# -  Publish your Workspace using the option on the left
# -  Check the published version of your report:
# 	-  Can you see everything you want us to grade?
#     -  Are all the graphics visible?
# -  Review the grading rubric. Have you included everything that will be graded?
# -  Head back to the [Certification Dashboard](https://app.datacamp.com/certification) to submit your practical exam report and record your presentation

# %%
import pandas as pd
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns 

product_sales= pd.read_csv("product_sales.csv")
dup_df = product_sales

# %%
product_sales.head()
# Out:
#    week  sales_method  ... nb_site_visits      state
# 0     2         Email  ...             24    Arizona
# 1     6  Email + Call  ...             28     Kansas
# 2     5          Call  ...             26  Wisconsin
# 3     4         Email  ...             25    Indiana
# 4     3         Email  ...             28   Illinois
#
# [5 rows x 8 columns]

# %%
product_sales.info()

# %%
product_sales.isna().sum()

# %%
unique_values = {col: product_sales[col].nunique() for col in product_sales.columns}
print(unique_values)

# %%
len(product_sales)
# Out:
# 15000

# %%
product_sales.describe()

# %%
product_sales['revenue'].describe()

# %%
product_sales['sales_method'].value_counts()

# %%
revenue_by_sales = product_sales.groupby('sales_method')['revenue'].sum()
revenue_by_sales

# %%
sales_method_map = {
    'Email': 'Email',
    'email': 'Email',
    'Call': 'Call',
    'call': 'Call',
    'Email + Call': 'Email + Call',
    'em + call': 'Email + Call'
}

# %%
product_sales['sales_method_grouped'] = product_sales['sales_method'].map(sales_method_map)
product_sales['sales_method_grouped'].value_counts()
# Out:
# Email           7466
# Call            4962
# Email + Call    2572
# Name: sales_method_grouped, dtype: int64

# %%
product_sales.dropna(inplace= True)

# %%
revenue_by_sales = product_sales.groupby('sales_method_grouped').agg(
    revenue= ('revenue', 'sum'),
    count = ('sales_method_grouped','count'))
revenue_by_sales
# Out:
#                         revenue  count
# sales_method_grouped
# Call                  227563.49   4781
# Email                 672317.83   6922
# Email + Call          408256.69   2223

# %%
product_sold = product_sales.groupby('sales_method_grouped').agg(
    nb_sold= ('nb_sold', 'sum'),
    count = ('sales_method_grouped','count'))
product_sold
# Out:
#                       nb_sold  count
# sales_method_grouped
# Call                    45424   4781
# Email                   67303   6922
# Email + Call            27091   2223

# %%
dup_df.dropna()
len(dup_df)

# %%
dup_df.describe()

# %%
# Create a histogram
#sns.histplot(dup_df['revenue'], color='blue', alpha=0.7)
sns.histplot(x='revenue', data=dup_df, color='green')
#plt.title()
plt.title('Histogram showing the Spread of Revenue')
plt.xlabel('Revenue')
plt.ylabel('Frequency')

# %%
# Create a boxplot
#sns.histplot(dup_df['revenue'], color='blue', alpha=0.7)
sns.boxplot(x='revenue', data=dup_df, color='green')
#plt.title()
plt.title('Boxplot showing the Spread of Revenue')
plt.xlabel('Revenue')
plt.ylabel('Frequency')

# %%
# Assuming `product_sales` is a pandas DataFrame with 'revenue' and 'revenue_by_sales' columns
sns.boxplot(data=dup_df, x='sales_method_grouped', y='revenue', palette="pastel")

# Add title and axis labels
plt.title("Boxplot of Revenue by Sales Method")
plt.xlabel("Sales Method")
plt.ylabel("Revenue")

# Show the plot
plt.show()

# %%
sns.countplot(data= dup_df, x= 'sales_method_grouped', y=None,color='green')
        
plt.title('Count by Sales Method')
plt.xlabel("Sales Method")
plt.ylabel("Count")
plt.show()

# %%
ax = product_sales['sales_method_grouped'].value_counts().plot(kind='bar', title='Count by Sales method', color="green")
ax.bar_label(ax.containers[0], padding=1)
#ax.set_ylim(0, 8000)
ax.set_xlabel("Sales Method")
ax.set_ylabel("Count")
plt.show()

# %%
sns.scatterplot(x='nb_sold', y='revenue', data=dup_df,hue='sales_method_grouped',style= 'sales_method_grouped')
plt.title('Revenue vs Product')
plt.show()

# %%
sns.scatterplot(x='nb_sold', y='revenue', data=dup_df,hue='sales_method_grouped')
plt.title('Revenue vs Week')
plt.show()

# %%
sns.scatterplot(x='nb_sold', y='revenue', data=dup_df)
plt.title('Revenue vs Week')
plt.show()

# %%
sns.histplot(x='nb_site_visits', data=dup_df, kde=True)
plt.title('Website visit in the last 6 months')
plt.show()

# %%
corr = dup_df['years_as_customer'].corr(dup_df['nb_site_visits'])
corr

# %%
sns.barplot(data=dup_df, x='week', y='revenue', hue= 'sales_method_grouped', errorbar=None)
plt.title('Revenues generated Weekly')
plt.show()

# %%
sns.barplot(data=dup_df, x='week', y='nb_sold',hue='sales_method_grouped', errorbar=None,palette='pastel')
plt.title('Products sold weekly by Sales method ')
plt.show()

# %%
sns.lineplot(data=dup_df, x='nb_sold', y='revenue', marker='o', color='blue')
plt.title('The line grapth of Revenue vs Number of products sold')
# Out:
# Text(0.5, 1.0, 'The line grapth of Revenue vs Number of products sold')

# %%
df_product = pd.read_csv('product_sales.csv')
df_product['revenue'].fillna(df_product['revenue'].median(), inplace=True)

# %%
len(df_product)

# %%
# Create a histogram
#sns.histplot(df['revenue'], color='blue', alpha=0.7)
sns.histplot(x='revenue', data=df_product, color='blue')
#plt.title()
plt.title('Histogram showing the Spread of Revenue')
plt.xlabel('Revenue')
plt.ylabel('Frequency')

# %%
sns.boxplot(data=product_sales, x='years_as_customer', palette="pastel")

# Add title and axis labels
plt.title("Boxplot of Years as customers")
plt.xlabel("Years as customers")
#plt.ylabel("Revenue")

# Show the plot
plt.show()
